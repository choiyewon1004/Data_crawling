# %% [markdown]
# # final

# %%
import pandas as pd
import numpy as np

import operator
from operator import itemgetter, attrgetter

import matplotlib.pyplot as plt

# %%
def count_frequency(my_list):
    
    count = {}
    
    for item in my_list:
        count[item] = count.get(item, 0) + 1
        
    return count

# %%
def findstyle(file):
    file = pd.read_csv(file)
    cloth =[]
    
    for line in range(len(file)):
        # clo_sty = file['style'][line]
        item = file['item'][line].split('{')[1:]
        length = len(item)

        for i in range(length):
            s = '{'+item[i]
            if i == length -1:
                s = s[:-1]
            else :
                s=s[:-2]

            d = eval(s)
            cloth.extend(d['item_style'])    
    return cloth

# %%
for i in range(1,13):
    result = []
    li_1 = findstyle(f"mon_{i}.csv")
    li_2 = findstyle(f"2_final_mon_{i}.csv")
    result.extend(li_1)
    result.extend(li_2)
    count = count_frequency(result)
    #print(count)
    
    count_order = sorted(
        count.items(),
        key= operator.itemgetter(1),
        reverse = True
    )
    #print(count_order)
    
    li_color_name =[]
    li_color_count = []

    li = list(count.keys())
    for ki in range(len(li)):
        if '색' in li[ki]:
            if li[ki] =='검정색' or li[ki]=='검정' : 
                continue
            li_color_name.append(li[ki])
            color_count =0
            for kj in range(len(li)):
                if li[ki][:-1] in li[kj]:
                    color_count += count[li[kj]]
            li_color_count.append(color_count)
    
    plt.figure(figsize=(15,6))
    plt.rcParams['font.family'] ='Malgun Gothic'
    plt.title(f'month[{i}] color')
    plt.bar(li_color_name, li_color_count, width=0.5)
    plt.xlabel('color')
    plt.ylabel('cnt')
    plt.show()

# %% [markdown]
# # Process

# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('mon_1.csv')

# %%
cloth =[]

# %%
cloth=[]
for line in range(2):
    clo_sty = file['style'][line]
    item = file['item'][line].split('{')[1:]
    length = len(item)
    result =[]
    
    for i in range(length):
        s = '{'+item[i]
        if i == length -1:
            s = s[:-1]
        else :
            s=s[:-2]
       
        d = eval(s)
        print(d)
        cloth.extend(d['item_style'])
# Out:
# {'item_title': '베이지 컬러의 스타디움 재킷', 'item_img': '//image.msscdn.net/mfile_s01/_street_images/88104/800.street_img_view163d7d83197457.jpg?', 'item_style': ['베이지', '스타디움재킷', '아우터', '베이지색']}
# {'item_title': '베이지 컬러의 어그 부츠', 'item_img': '//image.msscdn.net/mfile_s01/_street_images/88104/800.street_img_view263d7d83566de1.jpg?', 'item_style': ['어그부츠', '어그', '신발', '베이지색']}
# {'item_title': '블랙 컬러의 오버핏 점퍼', 'item_img': '//image.msscdn.net/mfile_s01/_street_images/88103/800.street_img_view163d7df34d5db5.jpg?', 'item_style': ['블랙', '점퍼', '오버핏', '아우터', '검정색']}
# {'item_title': '블랙 컬러의 와이드 팬츠', 'item_img': '//image.msscdn.net/mfile_s01/_street_images/88103/800.street_img_view263d7df387b65d.jpg?', 'item_style': ['블랙', '와이드팬츠', '하의', '검정색']}

# %%
cloth
# Out:
# ['베이지',
#  '스타디움재킷',
#  '아우터',
#  '베이지색',
#  '어그부츠',
#  '어그',
#  '신발',
#  '베이지색',
#  '블랙',
#  '점퍼',
#  '오버핏',
#  '아우터',
#  '검정색',
#  '블랙',
#  '와이드팬츠',
#  '하의',
#  '검정색']

# %% [markdown]
# ---

# %%
for line in range(2):
    clo_sty = file['style'][line]
    item = file['item'][line].split('{')[1:]
    length = len(item)
    result =[]
    
    for i in range(length):
        s = '{'+item[i]
        if i == length -1:
            s = s[:-1]
        else :
            s=s[:-2]
       
        d = eval(s)
        print()
        print(d['item_style'])
        
    print()
    print()
    print()
# Out:
# ['베이지', '스타디움재킷', '아우터', '베이지색']
#
# ['어그부츠', '어그', '신발', '베이지색']
#
#
#
#
# ['블랙', '점퍼', '오버핏', '아우터', '검정색']
#
# ['블랙', '와이드팬츠', '하의', '검정색']

# %%
for mon in range(1,13):
    file1 = pd.read_csv(f'mon_{mon}.csv')
    cloth =[]
    
    for line in range(len(file)):
        # clo_sty = file['style'][line]
        item = file['item'][line].split('{')[1:]
        length = len(item)

        for i in range(length):
            s = '{'+item[i]
            if i == length -1:
                s = s[:-1]
            else :
                s=s[:-2]

            d = eval(s)
            cloth.extend(d['item_style'])    

    print(f"{mon}월 스타일 ")
    print(set(cloth))
# Out:
# 1월 스타일
# {'슬립온', '여성핸드백', '여성롱코트', '점퍼', '스프라이트', '롱스커트', '녹색', '네이비', '숏재킷', '후드', '무스탕/퍼', '지브라', '라퍼지스토어', '숏패딩/숏헤비 아우터', '블루종', '치노팬츠', '오트밀', '벌룬핏팬츠', '첼시부츠', '카모', '코치재킷', '울블레이저', '플리스재킷', '패치', '크로스백', '캔버스', '검정색', '여자더비슈즈', '데님팬츠', '애니멀', '페이즐리', '하프코트', '여성', '갈색', '후드티셔츠', '퍼재킷', '미니백', '패턴', '데님롱스커트', '가죽숄더백', '베이지', '남자더비슈즈', '플리스', '아이보리', '롱코트', '분홍색', '코듀로이', '벨벳', '레더부츠', '트위드재킷', '코듀로이패딩', '파랑색', '브라운', '스커트', '하의', '헤드셋', '아우터', '블루', '더비슈즈', '버건디', '회색', '빨간색', '에코백', '하이탑스니커즈', '더플코트', '밀리터리재킷', '인디고', '크로스에코백', '바시티재킷', '스웨트팬츠', '볼캡', '와이드데님팬츠', '니트', '반스', '주황색', '팀버랜드', '핑크', '셀비지데님', '연청', '더블코트', '데님', '옐로우', '부츠', '레더', '닥터마틴', '흰색', '어그부츠', '코듀로이팬츠', '핸드백', '남자롱코트', '남자숏패딩', '블랙', '니트집업', '노란색', '보라색', '그린', '여자숏패딩', '오버핏', '카디건', '아디다스', '여자카고팬츠', '퍼플', '니트재킷', '남성', '팬츠', '여자롱코트', '싱글코트', '그레이', '패딩점퍼', '레이싱재킷', '숄더백', '스타디움재킷', '카멜', '블레이저', '패딩', '피시테일파카', '레그워머', '트위드', '기타패턴', '숏패딩', '신발', '항공점퍼', '베이
# 11월 스타일
# {'재킷', '집업재킷', '플리스베스트', '트위드스커트', '슬랙스', '트위드자켓', '와이드 코듀로이 팬츠', '롱스커트', '네이비', '녹색', '숏팬츠', '후드', '벌룬팬츠', '블루종', '오트밀', '카모', '웨스턴', '화이트팬츠', '힙색', '플리스재킷', '조거팬츠', '플리스자켓', '크로스백', '캔버스', '검정색', '하프집업', '데님팬츠', '와이드슬랙스', '갈색', '후드티셔츠', '은색', '퍼재킷', '미니백', '패턴', '플로럴', '무신사스탠다드', '베이지', '플리스', '퀼팅자켓', '버킷햇', '아이보리', '올블랙', '롱코트', '아식스', '분홍색', '코듀로이', '트위드재킷', '파랑색', '브라운', '부츠컷', '하의', '스커트', '레더팬츠', '진청', '아우터', '블루', '데저트부츠', '회색', '무신사 스탠다드', '빨간색', '에코백', '더플코트', '퀼팅', '밀리터리', '경량패딩', '타이다이', '인디고', '바시티재킷', '스웨트팬츠', '볼캡', '와이드데님팬츠', '모자', '레이싱', '진청데님', '니트', '비니', '반스', '주황색', '핑크', '트러커 재킷', '연청', '데님', '워싱', '부츠', '레더', '흰색', '스키니', '웨스턴부츠', '더블브레스티드', '핸드백', '코듀로이팬츠', '어그부츠', '밀리터리룩', '블랙', '보라색', '집업자켓', '피시테일', '그린', '오버핏', '카디건', '아디다스', '롱팬츠', '팬츠', '백팩', '하프팬츠', '체크스커트', '싱글코트', '그레이', '나이키', '트러커재킷', '아가일', '코트', '푸퍼 점퍼', '차콜', '숄더백', '후드집업', '트랙재킷', '블레이저', '스타디움재킷', '트위드', '기타패턴', '숏패딩', '신발', '항공점퍼', '와이드팬츠', '화이트', '베이지색', '크롭', '데님트러커재킷', '어그', '원피스', '레더재킷', '레이싱자켓', '미니스커트', '스퀘어토', '트랙탑자켓', '데님스커트', '레드', '카키', ' 니트 카디건', '트랙탑', '체크', '컨버스', '패딩베스트', '상의', '스웨터', '카세트백', '니트웨어', '와이드데님', '미니크로스백', '연청데님', '기타', '크롭자켓', '카고팬츠', '스웨이드', '워커', '크록스', '롱부츠', '토트백', '집업', '스웨트셔츠', '스니커즈', '무톤재킷', '스타디움', '하프집업스웨트셔츠'}
# 12월 스타일
# {'재킷', '집업재킷', '기타컬러', '점퍼', '숏코트', '롱스커트', '녹색', '네이비', '코듀로이자켓', '코듀로이재킷', '롱패딩', '숏패딩/숏헤비 아우터', '블루종', '치노팬츠', '하프집업니트', '첼시부츠', '여자숄더백', '카모', '어글리슈즈', '퍼', '플리스재킷', '부츠컷데님', '크로스백', '검정색', '데님팬츠', '와이드슬랙스', '애니멀', '은색', '갈색', '힐', '퍼재킷', '미니백', '패턴', '푸퍼', '청키라이너', '무신사스탠다드', '베이지', '플리스', '버킷햇', '퍼햇', '아이보리', '롱코트', '엠엘비', '아식스', '터틀넥니트', '실버', '분홍색', '로퍼', '코듀로이', '파랑색', '브라운', '부츠컷', '하의', '스커트', '뉴에라', '레더팬츠', '아우터', '블루', '더비슈즈', '회색', '푸마', '야상', '빨간색', '장갑', '더플코트', '인디고', '무톤', '모자', '스웨트팬츠', '볼캡', '와이드데님팬츠', '바시티재킷', '베이지팬츠', '니트', '울재킷', '케이블니트', '비니', '반스', '여자로퍼', '휠라', '주황색', '핑크', '트러커 재킷', '연청', '더블코트', '데님', '옐로우', '부츠', '레더', '닥터마틴', '흰색', '웨스턴부츠', '어그부츠', '더블브레스티드', '슬림핏', '블랙', '노란색', '플리스집업', '보라색', '피시테일', '그린', '여자숏패딩', '머플러', '오버핏', '아디다스', '카디건', '퍼플', '롱팬츠', '팬츠', '여자롱코트', '싱글코트', '그레이', '나이키', '패딩점퍼', '코트', '숄더백', '스타디움재킷', '패딩', '피시테일파카', '비건레더', '기타패턴', '숏패딩', '신발', '항공점퍼', '화이트', '베이지색', '레더재킷', '미니스커트', '트러커', '스퀘어토', '레드', '데님스커트', '와이드카고팬츠', '레오파드', '카키', '부츠컷팬츠', '컨버스', '슬림핏데님', '체크', '패딩베스트', '상의', '푸퍼패딩', '와이드데님', '오렌지', '연청데님', '기타', '미니크로스백', '카고팬츠', '스웨이드', '롱파카', '워커', '크록스', '롱부츠', '레더점퍼', '인디고데님', '스니커즈', '무톤재킷', '뉴발란스', '와이드팬츠', ' 크롭 카디건', '앵클부츠'}

# %%
li_color_name =[]
li_color_count = []

li = list(count.keys())
for i in range(len(li)):
    if '색' in li[i]:
        li_color_name.append(li[i])
        color_count =0
        #print(li[i] , ":" , count[li[i]])
        for j in range(len(li)):
            if li[i][:-1] in li[j]:
                #print(">",li[j] , ":" , count[li[j]])
                color_count += count[li[j]]
        #print("color_count ", color_count)
        li_color_count.append(color_count)
# Out:
# 베이지색 : 76
# > 베이지 : 44
# > 베이지색 : 76
# color_count  120
# 검정색 : 526
# > 검정색 : 526
# color_count  526
# 녹색 : 51
# > 녹색 : 51
# color_count  51
# 흰색 : 180
# > 흰색 : 180
# color_count  180
# 회색 : 66
# > 회색 : 66
# color_count  66
# 갈색 : 91
# > 갈색 : 91
# color_count  91
# 분홍색 : 18
# > 분홍색 : 18
# color_count  18
# 파랑색 : 42
# > 파랑색 : 42
# color_count  42
# 빨간색 : 17
# > 빨간색 : 17
# color_count  17
# 보라색 : 8
# > 보라색 : 8
# > 연보라 : 1
# color_count  9
# 주황색 : 9
# > 주황색 : 9
# color_count  9
# 노란색 : 8
# > 노란색 : 8
# color_count  8
# 힙색 : 1
# > 힙색 : 1
# color_count  1
# 은색 : 1
# > 은색 : 1
# color_count  1
